# %% [markdown]
# ## IBM Watson Studio : kaggle kernel
# ### 본 Notebook 문서의 목적은 ....
#    1. IBM Watson studio를 활용한 machine learning 방법을 익히기 위해서
#    2. Kaggle site 에서 가장 대표적인 beginner competition인 [Titianic:Machine Learning from disaster](https://www.kaggle.com/c/titanic) 중에서
#    3. 대표적인 machine leanring algorithm 을 다루고 있는  [Titanic EDA to ML](https://www.kaggle.com/dejavu23/titanic-eda-to-ml-beginner) 을 folk 하고
#    4. 해당 Python source 수행을 위해서 필요한 [Watson studio](https://dataplatform.ibm.com) 도구와 기능들을 활용하며
#    5. Source code 전후에 한글 주석은 이해를 돕기 위하여 추가하였습니다.
#
# **본래의 소스 코드 구성은 ...**
# * ** [Part 0: Watson studio 환경 구성하기](#Part-0:-Watson-studio-환경-구성하기)**
#
#
# * ** [Part 1: Exploratory Data Analysis](#Part-1:-Exploratory-Data-Analysis)**
#    understand the data by EDA and derive simple models by pandas as baseline
#
# * ** [Part 2: Data wrangling](#Part-2:-Data-wrangling)**
#    fill nan, convert categorical to numerical, create train and test data
#
# * ** [Part 3: Scikit-learn basic ML algorithms](#Part-3:-Scikit-learn-basic-ML-algorithms-and-comparison-of-model-results)**
#    implement logistic regression, KNN, decision tree, random forest, SVM
#
# * ** [Part 4: Comparison of Model  results](#Part-3:-Scikit-learn-basic-ML-algorithms-and-comparison-of-model-results)**
#    use metrics like confusion_matrix, classification_report, accuracy_score and implement k fold cross validation

# %% [markdown]
# ## Part 0: Watson studio 환경 구성하기

# %% [markdown]
#  * notebook 환경에 해당 모듈이 설치되지 않았을 경우 import error가 발생하며,
#    이 경우 아래와 같이 pip install command로 설치한다.
# *!pip numpy*
# *!pip install pandas*
# *!pip install matplotlib*
# *!pip install seaborn*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

from subprocess import check_output
print(check_output(["ls","-al", "."]).decode("utf8"))
# Out:
# total 16
# drwxr-x--- 2 dsxuser dsxuser 4096 Apr  4 01:40 .
# drwx------ 1 dsxuser dsxuser 4096 Apr  4 01:39 ..
# -rw-r----- 1 dsxuser dsxuser 2839 Apr  4 01:39 no_survivors.csv
# -rw-r----- 1 dsxuser dsxuser 2839 Apr  4 01:40 svc.csv

# %% [markdown]
# * notebook 환경에 설치된 SW configuration은 아래와 같이 확인 가능하다.
#
# ![env view detail](https://github.com/moreal70/IBM-Watson-Studio/raw/master/images/env_view_details.PNG)
#
#
# * SW configuration details
#
# ![SW configuration](https://github.com/moreal70/IBM-Watson-Studio/raw/master/images/notebook_sw_config.png)

# %%
# df_train = pd.read_csv("../input/train.csv")
# df_test = pd.read_csv("../input/test.csv")

# %% [markdown]
# * 원래 소스에서는 input data file이 notebook 수행 directory에서  "../input" 에 위치하지만,
# * kaggle에서  download 하여 Watson studio 로 upload 하여야 한다.
#
# ![kaggle data download](https://github.com/moreal70/IBM-Watson-Studio/raw/master/images/kaggle_data_download.PNG)

# %% [markdown]
# * IBM Watson studio 에서는 project file 로 loading 한다.
#
# ![upload file](https://github.com/moreal70/IBM-Watson-Studio/raw/master/images/upload_file.png)

# %% [markdown]
# * 기존의 data file read 하는 로직은 삭제하고,  "Insert to code" - "Insert pandas DataFrame" 을 이용하여 소스 코드를 추가 한다
#
# ![insert code](https://github.com/moreal70/IBM-Watson-Studio/raw/master/images/insert_code.png)

# %% [markdown]
# * Insert to code" 를 통해서 생성된 소스코드
# * 생성된 코드에서  DataFrame name을 df_train, df_test 로 수정 필요함

# %%
# The code was removed by DSX for sharing.

# %%
body = client_ace6f71a1b9946cbb684ca0d9e6c34c0.get_object(Bucket='projectparkhsu02d1be16ce7e164fc694f1c69332955f0b',Key='train.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_train = pd.read_csv(body)

# %% [markdown]
# ## Part 1: Exploratory Data Analysis

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# df_train has 891 entries, some values for Cabin and Age are missing

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# Also in df_test some values for Age and many values for Cabin are missing

# %%
df_test.shape, df_train.shape
# Out:
# ((418, 11), (891, 12))

# %% [markdown]
# Comparing distribution of features in df_train and df_test, Pclass and Age seem very similar, distributions for SibSo, Parch and Fare only slightly different

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# **Train data 에서 survived 건수는 얼마나 되는가 ?**

# %%
sns.countplot(x='Survived', data=df_train)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
print(df_train.Survived.sum()/df_train.Survived.count()*100,'%')
# Out:
# 38.3838383838 %

# %% [markdown]
# more people died than survived (38% survived)
#
# -> base model : no survivors
#
# submission : 0.627 accuracy

# %%
df_test['Survived'] = 0
df_test[['PassengerId', 'Survived']].to_csv('no_survivors.csv', index=False)
print(df_test.head())
# !ls -al
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         0
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         0
# total 16
# drwxr-x--- 2 dsxuser dsxuser 4096 Apr  4 01:40 .
# drwx------ 1 dsxuser dsxuser 4096 Apr  4 01:39 ..
# -rw-r----- 1 dsxuser dsxuser 2839 Apr  4 01:54 no_survivors.csv
# -rw-r----- 1 dsxuser dsxuser 2839 Apr  4 01:40 svc.csv

# %% [markdown]
# **Sex: Female more likely to survive than male**

# %%
df_train.groupby(['Survived','Sex'])['Survived'].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
sns.factorplot(x='Sex', col='Survived', kind='count', data=df_train);
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
print("% of women survived: " , df_train[df_train.Sex == 'female'].Survived.sum()/df_train[df_train.Sex == 'female'].Survived.count())
print("% of men survived:   " , df_train[df_train.Sex == 'male'].Survived.sum()/df_train[df_train.Sex == 'male'].Survived.count())
# Out:
# % of women survived:  0.742038216561
# % of men survived:    0.188908145581

# %%
f,ax=plt.subplots(1,2,figsize=(16,7))
df_train['Survived'][df_train['Sex']=='male'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[0],shadow=True)
df_train['Survived'][df_train['Sex']=='female'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[1],shadow=True)
ax[0].set_title('Survived (male)')
ax[1].set_title('Survived (female)')

plt.show()

# %% [markdown]
# Women were more likely to survive than men
#
# 74 % of women survived
# but only 19% of men
# (in training set)
#
# second model :
# all women survived and all men died
#
# submission : 0.766 accuracy

# %%
#df_test['Survived'] = df_test.Sex == 'female'
#df_test['Survived'] = df_test.Survived.apply(lambda x: int(x))
#df_test[['PassengerId', 'Survived']].to_csv('women_survive.csv', index=False)

# %% [markdown]
# **Passenger Class : Survival rate decreases with Pclass**

# %%
pd.crosstab(df_train.Pclass, df_train.Survived, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow0_col0 {
#             background-color:  #ffff00;
#         }    #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow0_col1 {
#             background-color:  #ffce00;
#         }    #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow0_col2 {
#             background-color:  #fff400;
#         }    #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow1_col0 {
#             background-color:  #fff600;
#         }    #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow1_col1 {
#             background-color:  #ffff00;
#         }    #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow1_col2 {
#             background-color:  #ffff00;
#         }    #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow2_col0 {
#             background-color:  #ff6000;
#         }    #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow2_col1 {
#             background-color:  #ffdf00;
#         }    #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow2_col2 {
#             background-color:  #ff9000;
#         }    #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow3_col0 {
#             background-color:  #ff0000;
#         }    #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow3_col1 {
#             background-color:  #ff0000;
#         }    #T_1cd0ad70_37ab_11e8_b582_5695a4169eberow3_col2 {
#             background-color:  #ff0000;
#         }</style>
# <table id="T_1cd0ad70_37ab_11e8_b582_5695a4169ebe" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_1cd0ad70_37ab_11e8_b582_5695a4169ebelevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow0_col0" class="data row0 col0" >80</td>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow0_col1" class="data row0 col1" >136</td>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow0_col2" class="data row0 col2" >216</td>
#     </tr>    <tr>
#         <th id="T_1cd0ad70_37ab_11e8_b582_5695a4169ebelevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow1_col0" class="data row1 col0" >97</td>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow1_col1" class="data row1 col1" >87</td>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow1_col2" class="data row1 col2" >184</td>
#     </tr>    <tr>
#         <th id="T_1cd0ad70_37ab_11e8_b582_5695a4169ebelevel0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow2_col0" class="data row2 col0" >372</td>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow2_col1" class="data row2 col1" >119</td>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow2_col2" class="data row2 col2" >491</td>
#     </tr>    <tr>
#         <th id="T_1cd0ad70_37ab_11e8_b582_5695a4169ebelevel0_row3" class="row_heading level0 row3" >All</th>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow3_col0" class="data row3 col0" >549</td>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow3_col1" class="data row3 col1" >342</td>
#         <td id="T_1cd0ad70_37ab_11e8_b582_5695a4169eberow3_col2" class="data row3 col2" >891</td>
#     </tr></tbody>
# </table>

# %%
print("% of survivals in") 
print("Pclass=1 : ", df_train.Survived[df_train.Pclass == 1].sum()/df_train[df_train.Pclass == 1].Survived.count())
print("Pclass=2 : ", df_train.Survived[df_train.Pclass == 2].sum()/df_train[df_train.Pclass == 2].Survived.count())
print("Pclass=3 : ", df_train.Survived[df_train.Pclass == 3].sum()/df_train[df_train.Pclass == 3].Survived.count())
# Out:
# % of survivals in
# Pclass=1 :  0.62962962963
# Pclass=2 :  0.472826086957
# Pclass=3 :  0.242362525458

# %%
sns.factorplot('Pclass','Survived', data=df_train)
plt.show()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# **Passenger Class and Sex :**
#
# **Almost all women in Pclass 1 and 2 survived and nearly all men in Pclass 2 and 3 died**

# %%
pd.crosstab([df_train.Sex, df_train.Survived], df_train.Pclass, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow0_col0 {
#             background-color:  #ffff00;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow0_col1 {
#             background-color:  #ffff00;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow0_col2 {
#             background-color:  #fff100;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow0_col3 {
#             background-color:  #ffff00;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow1_col0 {
#             background-color:  #ff9600;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow1_col1 {
#             background-color:  #ffa300;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow1_col2 {
#             background-color:  #fff100;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow1_col3 {
#             background-color:  #ffcf00;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow2_col0 {
#             background-color:  #ffa700;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow2_col1 {
#             background-color:  #ff8500;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow2_col2 {
#             background-color:  #ff6e00;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow2_col3 {
#             background-color:  #ff8500;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow3_col0 {
#             background-color:  #ffcd00;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow3_col1 {
#             background-color:  #fff000;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow3_col2 {
#             background-color:  #ffff00;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow3_col3 {
#             background-color:  #fff700;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow4_col0 {
#             background-color:  #ff0000;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow4_col1 {
#             background-color:  #ff0000;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow4_col2 {
#             background-color:  #ff0000;
#         }    #T_1cfc07f4_37ab_11e8_b582_5695a4169eberow4_col3 {
#             background-color:  #ff0000;
#         }</style>
# <table id="T_1cfc07f4_37ab_11e8_b582_5695a4169ebe" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="index_name level1" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_1cfc07f4_37ab_11e8_b582_5695a4169ebelevel0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#         <th id="T_1cfc07f4_37ab_11e8_b582_5695a4169ebelevel1_row0" class="row_heading level1 row0" >0</th>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow0_col0" class="data row0 col0" >3</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow0_col1" class="data row0 col1" >6</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow0_col2" class="data row0 col2" >72</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow0_col3" class="data row0 col3" >81</td>
#     </tr>    <tr>
#         <th id="T_1cfc07f4_37ab_11e8_b582_5695a4169ebelevel1_row1" class="row_heading level1 row1" >1</th>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow1_col0" class="data row1 col0" >91</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow1_col1" class="data row1 col1" >70</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow1_col2" class="data row1 col2" >72</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow1_col3" class="data row1 col3" >233</td>
#     </tr>    <tr>
#         <th id="T_1cfc07f4_37ab_11e8_b582_5695a4169ebelevel0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#         <th id="T_1cfc07f4_37ab_11e8_b582_5695a4169ebelevel1_row2" class="row_heading level1 row2" >0</th>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow2_col0" class="data row2 col0" >77</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow2_col1" class="data row2 col1" >91</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow2_col2" class="data row2 col2" >300</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow2_col3" class="data row2 col3" >468</td>
#     </tr>    <tr>
#         <th id="T_1cfc07f4_37ab_11e8_b582_5695a4169ebelevel1_row3" class="row_heading level1 row3" >1</th>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow3_col0" class="data row3 col0" >45</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow3_col1" class="data row3 col1" >17</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow3_col2" class="data row3 col2" >47</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow3_col3" class="data row3 col3" >109</td>
#     </tr>    <tr>
#         <th id="T_1cfc07f4_37ab_11e8_b582_5695a4169ebelevel0_row4" class="row_heading level0 row4" >All</th>
#         <th id="T_1cfc07f4_37ab_11e8_b582_5695a4169ebelevel1_row4" class="row_heading level1 row4" ></th>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow4_col0" class="data row4 col0" >216</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow4_col1" class="data row4 col1" >184</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow4_col2" class="data row4 col2" >491</td>
#         <td id="T_1cfc07f4_37ab_11e8_b582_5695a4169eberow4_col3" class="data row4 col3" >891</td>
#     </tr></tbody>
# </table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=df_train)
plt.show()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1508: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %% [markdown]
# **Embarked : Survival rate lowest for S and highest for C**

# %%
sns.factorplot(x='Survived', col='Embarked', kind='count', data=df_train);
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
sns.factorplot('Embarked','Survived', data=df_train)
plt.show()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# **Embarked and Sex**

# %%
sns.factorplot('Embarked','Survived', hue= 'Sex', data=df_train)
plt.show()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1508: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %% [markdown]
# **Embarked, Pclass and Sex :**
#
# ** Practically all women of Pclass 2 that embarked in C and Q survived, also nearly all women of Pclass 1 survived. **
#
# ** All men of Pclass 1 and 2 embarked in Q died, survival rate for men in Pclass 2 and 3 is always below 0.2 **
#
# ** For the remaining men in Pclass 1 that embarked in S and Q, survival rate is approx. 0.4 **

# %%
sns.factorplot('Embarked','Survived', col='Pclass', hue= 'Sex', data=df_train)
plt.show()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1508: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
pd.crosstab([df_train.Survived], [df_train.Sex, df_train.Pclass, df_train.Embarked], margins=True)
# Out:
# Sex      female                              male                            \
# Pclass        1         2          3            1          2          3
# Embarked      C  Q   S  C  Q   S   C   Q   S    C  Q   S   C  Q   S   C   Q
# Survived
# 0             1  0   2  0  0   6   8   9  55   25  1  51   8  1  82  33  36
# 1            42  1  46  7  2  61  15  24  33   17  0  28   2  0  15  10   3
# All          43  1  48  7  2  67  23  33  88   42  1  79  10  1  97  43  39
#
# Sex            All
# Pclass
# Embarked    S
# Survived
# 0         231  549
# 1          34  340
# All       265  889

# %% [markdown]
# third model :
# based on PClass, Sex and Embarked ,
# submission : 0.779 accuracy

# %%
# model 3
df_test['Survived'] = 0
# all women survived
df_test.loc[ (df_test.Sex == 'female'), 'Survived'] = 1
# except for those in Pclass 3 and embarked in S
df_test.loc[ (df_test.Sex == 'female') & (df_test.Pclass == 3) & (df_test.Embarked == 'S') , 'Survived'] = 0
#df_test[['PassengerId', 'Survived']].to_csv('embarked_pclass_sex.csv', index=False)

# %% [markdown]
# **Age:  continuous numerical  to  8 bins **

# %%
for df in [df_train, df_test]:
    df['Age_bin']=np.nan
    for i in range(8,0,-1):
        df.loc[ df['Age'] <= i*10, 'Age_bin'] = i

# %%
print(df_train[['Age' , 'Age_bin']].head(10))
# Out:
#     Age  Age_bin
# 0  22.0      3.0
# 1  38.0      4.0
# 2  26.0      3.0
# 3  35.0      4.0
# 4  35.0      4.0
# 5   NaN      NaN
# 6  54.0      6.0
# 7   2.0      1.0
# 8  27.0      3.0
# 9  14.0      2.0

# %%
sns.factorplot('Age_bin','Survived',hue='Sex',data=df_train)
plt.show()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1508: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
sns.factorplot('Age_bin','Survived', col='Pclass' , row = 'Sex', data=df_train)
plt.show()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.Age_bin, df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col0 {
#             background-color:  #ffaa00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col1 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col2 {
#             background-color:  #ffea00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col3 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col4 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col5 {
#             background-color:  #ffee00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col6 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col7 {
#             background-color:  #fff300;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col8 {
#             background-color:  #fffb00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col9 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col10 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col11 {
#             background-color:  #fff700;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col12 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col13 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col14 {
#             background-color:  #ffbb00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col15 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col16 {
#             background-color:  #ffea00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col17 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col18 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col19 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col20 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col21 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col22 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow0_col23 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col0 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col1 {
#             background-color:  #ff8700;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col2 {
#             background-color:  #ffea00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col3 {
#             background-color:  #ff4700;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col4 {
#             background-color:  #ff8e00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col5 {
#             background-color:  #ffea00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col6 {
#             background-color:  #ff8300;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col7 {
#             background-color:  #ff9700;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col8 {
#             background-color:  #fffb00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col9 {
#             background-color:  #ff8200;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col10 {
#             background-color:  #ffa400;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col11 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col12 {
#             background-color:  #ffb100;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col13 {
#             background-color:  #ff8e00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col14 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col15 {
#             background-color:  #ff8f00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col16 {
#             background-color:  #ffd500;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col17 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col18 {
#             background-color:  #ffd100;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col19 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col20 {
#             background-color:  #ffaa00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col21 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col22 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow1_col23 {
#             background-color:  #ffcb00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col0 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col1 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col2 {
#             background-color:  #ffd500;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col3 {
#             background-color:  #ffd500;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col4 {
#             background-color:  #ff7f00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col5 {
#             background-color:  #ff7100;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col6 {
#             background-color:  #ffc400;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col7 {
#             background-color:  #ff7500;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col8 {
#             background-color:  #ff6600;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col9 {
#             background-color:  #ffc100;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col10 {
#             background-color:  #ff7900;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col11 {
#             background-color:  #ff5e00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col12 {
#             background-color:  #ff9c00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col13 {
#             background-color:  #ff9c00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col14 {
#             background-color:  #ff5500;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col15 {
#             background-color:  #ff9900;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col16 {
#             background-color:  #ff3f00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col17 {
#             background-color:  #ff0000;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col18 {
#             background-color:  #ff2e00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col19 {
#             background-color:  #ff5500;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col20 {
#             background-color:  #ff5500;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col21 {
#             background-color:  #ff5500;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col22 {
#             background-color:  #ff0000;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow2_col23 {
#             background-color:  #ff8b00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow3_col0 {
#             background-color:  #ff5500;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow3_col1 {
#             background-color:  #ff7800;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow3_col2 {
#             background-color:  #ffff00;
#         }    #T_1fc0b5d4_37ab_11e8_b582_5695a4169eberow3_col3 {
#             background-color:  #ffe300;
#         }    #T_1fc0b5d4_37ab_11e8_b5

# %% [markdown]
# For passengers in Age_bin = 1 (younger than 10) : All male in Pclass 1 and 2 survived
#
# All female in Pclass 3 and Age_bin = 5 died.
#
# (Survival rate for female in Pclass 3 and Age_bin = 4 is below 50%)
#
# (Survival rate for male in Pclass 1 and Age_bin = 4 is above 50%)

# %%
# in Pclass 1 and 2 all men in Age_bin = 1 survived
df_test.loc[ (df_test.Sex == 'male') & (df_test.Pclass == 1) & (df_test.Age_bin == 1), 'Survived'] = 1
df_test.loc[ (df_test.Sex == 'male') & (df_test.Pclass == 2) & (df_test.Age_bin == 1), 'Survived'] = 1

# %% [markdown]
# **SibSp and Parch**

# %%
sns.factorplot('SibSp','Survived', col='Pclass' , row = 'Sex', data=df_train)
plt.show()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.SibSp, df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_209de878_37ab_11e8_b582_5695a4169eberow0_col0 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col1 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col2 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col3 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col4 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col5 {
#             background-color:  #ffd900;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col6 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col7 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col8 {
#             background-color:  #ffdb00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col9 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col10 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col11 {
#             background-color:  #ff6a00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col12 {
#             background-color:  #ffd200;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col13 {
#             background-color:  #ffcc00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col14 {
#             background-color:  #ff9200;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow0_col15 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col0 {
#             background-color:  #ffa700;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col1 {
#             background-color:  #ffac00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col2 {
#             background-color:  #fff300;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col3 {
#             background-color:  #ff7a00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col4 {
#             background-color:  #ff9300;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col5 {
#             background-color:  #ffe700;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col6 {
#             background-color:  #ff6600;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col7 {
#             background-color:  #ff9f00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col8 {
#             background-color:  #ffc900;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col9 {
#             background-color:  #ff5500;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col10 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col11 {
#             background-color:  #ffea00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col12 {
#             background-color:  #fff000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col13 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col14 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow1_col15 {
#             background-color:  #ffcf00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col0 {
#             background-color:  #ff9200;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col1 {
#             background-color:  #ff7300;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col2 {
#             background-color:  #ff5d00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col3 {
#             background-color:  #ffcc00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col4 {
#             background-color:  #ffac00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col5 {
#             background-color:  #ffa800;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col6 {
#             background-color:  #ffcc00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col7 {
#             background-color:  #ff7f00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col8 {
#             background-color:  #ff9200;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col9 {
#             background-color:  #ffaa00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col10 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col11 {
#             background-color:  #ffaa00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col12 {
#             background-color:  #ff6900;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col13 {
#             background-color:  #ff3300;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col14 {
#             background-color:  #ff6d00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow2_col15 {
#             background-color:  #ff8500;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col0 {
#             background-color:  #ffcb00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col1 {
#             background-color:  #fff200;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col2 {
#             background-color:  #fffe00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col3 {
#             background-color:  #ffcf00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col4 {
#             background-color:  #ffec00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col5 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col6 {
#             background-color:  #ffcc00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col7 {
#             background-color:  #ffdf00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col8 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col9 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col10 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col11 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col12 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col13 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col14 {
#             background-color:  #ffff00;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow3_col15 {
#             background-color:  #fff700;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col0 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col1 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col2 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col3 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col4 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col5 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col6 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col7 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col8 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col9 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col10 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eberow4_col11 {
#             background-color:  #ff0000;
#         }    #T_209de878_37ab_11e8_b582_5695a4169eber

# %% [markdown]
# For males, no survival rate above 0.5 for any values of SibSp.
# For females, passengers with SibSp = 3 and Pclass = 3 died, also all females with SibSp > 4 died.
# For females with SibSp = 1 and Pclass = 3 survival rate is below 0.5

# %%
# all females with SibSp > 7 died
df_test.loc[ (df_test.Sex == 'female') & (df_test.SibSp > 7) , 'Survived'] = 0

# %%
sns.factorplot('Parch','Survived', col='Pclass' , row = 'Sex', data=df_train)
plt.show()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.Parch, df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col0 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col1 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col2 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col3 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col4 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col5 {
#             background-color:  #ffe400;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col6 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col7 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col8 {
#             background-color:  #ffa600;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col9 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col10 {
#             background-color:  #ffaa00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col11 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col12 {
#             background-color:  #ff5500;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col13 {
#             background-color:  #ff6600;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col14 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow0_col15 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col0 {
#             background-color:  #ff9e00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col1 {
#             background-color:  #ffba00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col2 {
#             background-color:  #fff400;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col3 {
#             background-color:  #ff7300;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col4 {
#             background-color:  #ff7b00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col5 {
#             background-color:  #ffea00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col6 {
#             background-color:  #ff8600;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col7 {
#             background-color:  #ff4f00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col8 {
#             background-color:  #ffdf00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col9 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col10 {
#             background-color:  #ffaa00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col11 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col12 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col13 {
#             background-color:  #ffcc00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col14 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow1_col15 {
#             background-color:  #ffcf00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col0 {
#             background-color:  #ff9e00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col1 {
#             background-color:  #ff6900;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col2 {
#             background-color:  #ff5900;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col3 {
#             background-color:  #ffad00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col4 {
#             background-color:  #ffce00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col5 {
#             background-color:  #ffb300;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col6 {
#             background-color:  #fff200;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col7 {
#             background-color:  #ffcf00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col8 {
#             background-color:  #ffb300;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col9 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col10 {
#             background-color:  #ffaa00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col11 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col12 {
#             background-color:  #ffaa00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col13 {
#             background-color:  #ffcc00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col14 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow2_col15 {
#             background-color:  #ff8500;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col0 {
#             background-color:  #ffc800;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col1 {
#             background-color:  #fffa00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col2 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col3 {
#             background-color:  #ffde00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col4 {
#             background-color:  #ffce00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col5 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col6 {
#             background-color:  #ffd700;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col7 {
#             background-color:  #ffdf00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col8 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col9 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col10 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col11 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col12 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col13 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col14 {
#             background-color:  #ffff00;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow3_col15 {
#             background-color:  #fff700;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col0 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col1 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col2 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col3 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col4 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col5 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col6 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col7 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col8 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col9 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col10 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eberow4_col11 {
#             background-color:  #ff0000;
#         }    #T_2182cf24_37ab_11e8_b582_5695a4169eber

# %% [markdown]
# Very similar to SibSp - 1 , but different values  ?
# For females with Parch = 2 and Pclass = 3 survival rate is below 0.5
# All females with Parch = 4 and Pclass = 3 died.
# All females with Parch > 4 died.
# (For females with Parch = 1 and Pclass = 3 survival rate is below 0.5)
# For males,all survival rates below 0.5 for any values of Parch, except for Parch = 2 and Pclass = 1.

# %%
# survival rate is below 0.5 for females with Parch = 2 and Pclass = 3 
#df_test.loc[ (df_test.Sex == 'female') & (df_test.Pclass == 3) & (df_test.Parch == 2), 'Survived'] = 0

# All females with Parch = 4 and Pclass = 3 died
##df_test.loc[ (df_test.Sex == 'female') & (df_test.Pclass == 3) & (df_test.Parch == 4), 'Survived'] = 0

# all females with Parch > 4 died
#df_test.loc[ (df_test.Sex == 'female') & (df_test.Parch > 4) , 'Survived'] = 0

# For males with Parch = 2 and Pclass = 1 survival rate is above 0.5
##df_test.loc[ (df_test.Sex == 'male') & (df_test.Pclass == 1) & (df_test.Parch == 1) , 'Survived'] = 1

#df_test.head(20)

# %% [markdown]
# **Fare:  continuous numerical  to  12 bins **

# %%
sns.distplot(df_train['Fare'])
plt.show()

# %%
for df in [df_train, df_test]:
    df['Fare_bin']=np.nan
    for i in range(12,0,-1):
        df.loc[ df['Fare'] <= i*50, 'Fare_bin'] = i

# %%
sns.factorplot('Fare_bin','Survived', col='Pclass' , row = 'Sex', data=df_train)
plt.show()
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.Fare_bin, df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col0 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col1 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col2 {
#             background-color:  #fff000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col3 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col4 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col5 {
#             background-color:  #ffc900;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col6 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col7 {
#             background-color:  #ffdf00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col8 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col9 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col10 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow0_col11 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col0 {
#             background-color:  #ffde00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col1 {
#             background-color:  #ffa300;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col2 {
#             background-color:  #ffee00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col3 {
#             background-color:  #ff7100;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col4 {
#             background-color:  #ffb600;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col5 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col6 {
#             background-color:  #ff5f00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col7 {
#             background-color:  #ff7f00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col8 {
#             background-color:  #ff5d00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col9 {
#             background-color:  #ff5500;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col10 {
#             background-color:  #ffaa00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow1_col11 {
#             background-color:  #ffcf00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col0 {
#             background-color:  #ff7500;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col1 {
#             background-color:  #ff8800;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col2 {
#             background-color:  #ff6b00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col3 {
#             background-color:  #ffbb00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col4 {
#             background-color:  #ff4900;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col5 {
#             background-color:  #ff9200;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col6 {
#             background-color:  #ffca00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col7 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col8 {
#             background-color:  #ffa200;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col9 {
#             background-color:  #ffaa00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col10 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow2_col11 {
#             background-color:  #ff8500;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col0 {
#             background-color:  #ffb500;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col1 {
#             background-color:  #ffef00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col2 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col3 {
#             background-color:  #ffd300;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col4 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col5 {
#             background-color:  #ffa400;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col6 {
#             background-color:  #ffd500;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col7 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col8 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col9 {
#             background-color:  #ffff00;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col10 {
#             background-color:  #ff5500;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow3_col11 {
#             background-color:  #fff700;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col0 {
#             background-color:  #ff0000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col1 {
#             background-color:  #ff0000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col2 {
#             background-color:  #ff0000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col3 {
#             background-color:  #ff0000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col4 {
#             background-color:  #ff0000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col5 {
#             background-color:  #ff0000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col6 {
#             background-color:  #ff0000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col7 {
#             background-color:  #ff0000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col8 {
#             background-color:  #ff0000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col9 {
#             background-color:  #ff0000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col10 {
#             background-color:  #ff0000;
#         }    #T_22765be4_37ab_11e8_b582_5695a4169eberow4_col11 {
#             background-color:  #ff0000;
#         }</style>
# <table id="T_22765be4_37ab_11e8_b582_5695a4169ebe" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Fare_bin</th>
#         <th class="col_heading level0 col0" colspan=3>1.0</th>
#         <th class="col_heading level0 col3" colspan=3>2.0</th>
#         <th class="col_heading level0 col6" >3.0</th>
#         <th class="col_heading level0 col7" >4.0</th>
#         <th class="col_heading level0 col8" >5.0</th>
#         <th class="col_heading level0 col9" >6.0</th>
#         <th class="col_heading level0 col10" >11.0</th>
#         <th class="col_heading level0 col11" >All</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level1" >Pclass</th>
#         <th class="col_heading level1 col0" >1</th>
#         <th class="col_heading level1 col1" >2</th>
#         <th class="col_heading level1 col2" >3</th>
#         <th class="col_heading level1 col3" >1</th>
#         <th class="col_heading level1 col4" >2</th>
#         <th class="col_heading level1 col5" >3</th>
#         <th class="col_heading level1 col6" >1</th>
#         <th class="col_heading level1 col7" >1</th>
#         <th class="col_heading level1 col8" >1</th>
#         <th class="col_heading level1 col9" >1</th>
#         <th class="col_heading level1 col10" >1</th>
#         <th class="col_heading level1 col11" ></th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="index_name level1" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank"

# %%
# males in Fare_bin = 11 survived
df_test.loc[ (df_test.Sex == 'male') & (df_test.Fare_bin == 11), 'Survived'] = 1

# %% [markdown]
# fourth model : model 3 + Age_bin, SibSp, Parch and Fare_bin
# submission : 0.789 accuracy

# %%
# model 4
# df_test[['PassengerId', 'Survived']].to_csv('model_4.csv', index=False)

# %%
df_test.drop(['Survived'],axis=1,inplace=True)

# %% [markdown]
# ## Part 2: Data wrangling
#
# building two new dataframes df_train_ml and df_test_ml
# these will have only ordinal features and no missing values so they can be used for ML algorithms
# converting categorical to numerical by pd.get_dummies
# dropping all features that seem to be not useful for prediction
# Then use the Standard scaler and apply train/test split

# %%
df_train_ml = df_train.copy()
df_test_ml = df_test.copy()

# %%
df_train_ml = pd.get_dummies(df_train_ml, columns=['Sex', 'Embarked', 'Pclass'], drop_first=True)
df_train_ml.drop(['PassengerId','Name','Ticket', 'Cabin', 'Age_bin', 'Fare_bin'],axis=1,inplace=True)
df_train_ml.dropna(inplace=True)

# %%
passenger_id = df_test_ml['PassengerId']
df_test_ml = pd.get_dummies(df_test_ml, columns=['Sex', 'Embarked', 'Pclass'], drop_first=True)
df_test_ml.drop(['PassengerId','Name','Ticket', 'Cabin', 'Age_bin', 'Fare_bin'],axis=1,inplace=True)

# %%
df_train_ml.head(10)
# Out:
#     Survived   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  Embarked_S  \
# 0          0  22.0      1      0   7.2500         1           0           1
# 1          1  38.0      1      0  71.2833         0           0           0
# 2          1  26.0      0      0   7.9250         0           0           1
# 3          1  35.0      1      0  53.1000         0           0           1
# 4          0  35.0      0      0   8.0500         1           0           1
# 6          0  54.0      0      0  51.8625         1           0           1
# 7          0   2.0      3      1  21.0750         1           0           1
# 8          1  27.0      0      2  11.1333         0           0           1
# 9          1  14.0      1      0  30.0708         0           0           0
# 10         1   4.0      1      1  16.7000         0           0           1
#
#     Pclass_2  Pclass_3
# 0          0         1
# 1          0         0
# 2          0         1
# 3          0         0
# 4          0         1
# 6          0         0
# 7          0         1
# 8          0         1
# 9          1         0
# 10         0         1

# %%
df_train_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 890
# Data columns (total 10 columns):
# Survived      714 non-null int64
# Age           714 non-null float64
# SibSp         714 non-null int64
# Parch         714 non-null int64
# Fare          714 non-null float64
# Sex_male      714 non-null uint8
# Embarked_Q    714 non-null uint8
# Embarked_S    714 non-null uint8
# Pclass_2      714 non-null uint8
# Pclass_3      714 non-null uint8
# dtypes: float64(2), int64(3), uint8(5)
# memory usage: 37.0 KB

# %%
df_test_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
# Age           332 non-null float64
# SibSp         418 non-null int64
# Parch         418 non-null int64
# Fare          417 non-null float64
# Sex_male      418 non-null uint8
# Embarked_Q    418 non-null uint8
# Embarked_S    418 non-null uint8
# Pclass_2      418 non-null uint8
# Pclass_3      418 non-null uint8
# dtypes: float64(2), int64(2), uint8(5)
# memory usage: 15.2 KB

# %%
#df_test_ml.drop(['Survived'],axis=1,inplace=True)
df_test_ml.head()
# Out:
#     Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  Embarked_S  Pclass_2  \
# 0  34.5      0      0   7.8292         1           1           0         0
# 1  47.0      1      0   7.0000         0           0           1         0
# 2  62.0      0      0   9.6875         1           1           0         1
# 3  27.0      0      0   8.6625         1           0           1         0
# 4  22.0      1      1  12.2875         0           0           1         0
#
#    Pclass_3
# 0         1
# 1         1
# 2         0
# 3         1
# 4         1

# %%
df_test_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
# Age           332 non-null float64
# SibSp         418 non-null int64
# Parch         418 non-null int64
# Fare          417 non-null float64
# Sex_male      418 non-null uint8
# Embarked_Q    418 non-null uint8
# Embarked_S    418 non-null uint8
# Pclass_2      418 non-null uint8
# Pclass_3      418 non-null uint8
# dtypes: float64(2), int64(2), uint8(5)
# memory usage: 15.2 KB

# %%
corr = df_train_ml.corr()
sns.heatmap(corr)

# %% [markdown]
# **Standard Scaler**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# for df_train_ml
scaler.fit(df_train_ml.drop('Survived',axis=1))
scaled_features = scaler.transform(df_train_ml.drop('Survived',axis=1))
df_train_ml_sc = pd.DataFrame(scaled_features, columns=df_train_ml.columns[:-1])

# for df_test_ml
df_test_ml.fillna(df_test_ml.mean(), inplace=True)
scaler.fit(df_test_ml)
scaled_features = scaler.transform(df_test_ml)
df_test_ml_sc = pd.DataFrame(scaled_features, columns=df_test_ml.columns)

# %% [markdown]
# **train_test_split**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_train_ml.drop('Survived',axis=1), df_train_ml['Survived'], test_size=0.30, random_state=101)
X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(df_train_ml_sc, df_train_ml['Survived'], test_size=0.30, random_state=101)

# %% [markdown]
# **all data for submission**

# %%
# unscaled
X_train_all = df_train_ml.drop('Survived',axis=1)
y_train_all = df_train_ml['Survived']
X_test_all = df_test_ml

# scaled
X_train_all_sc = df_train_ml_sc
y_train_all_sc = df_train_ml['Survived']
X_test_all_sc = df_test_ml_sc

# %% [markdown]
# **fillna: fill nan with mean values for that column**

# %%
X_test_all.fillna(X_test_all.mean(), inplace=True)
print("*")
# Out:
# *

# %% [markdown]
# ## Part 3: Scikit-learn basic ML algorithms and comparison of model results
#
# **Test simple sklearn models and compare by metrics**
#
#
# **1. We test the following classifiers from scikit-learn:**
# * Logistic regression
# * Gaussian Naive Bayes
# * K nearest neighbors KNN
# * Decision tree classifier
# * Random forest classifier
# * SVM classifier
#
# **2. For comparison of the results we use these metrics:**
# * accuracy_score,
# * classification_report,
# * confusion_matrix
#
#
# **First we apply the data from test/train split to get a first overview of the model performance.
# Later we use the k fold cross validation which gives a better estimate for out of sample data.**

# %% [markdown]
# ### 1. Over all model testing

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[107  16]
#  [ 32  60]]
#              precision    recall  f1-score   support
#
#           0       0.77      0.87      0.82       123
#           1       0.79      0.65      0.71        92
#
# avg / total       0.78      0.78      0.77       215
#
# 0.776744186047

# %% [markdown]
# Train again for all data and submit

# %%
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all)

# %%
sub_logreg = pd.DataFrame()
sub_logreg['PassengerId'] = df_test['PassengerId']
sub_logreg['Survived'] = pred_all_logreg
#sub_logmodel.to_csv('logmodel.csv',index=False)

# %% [markdown]
# **Gaussian Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
pred_gnb = gnb.predict(X_test)
print(confusion_matrix(y_test, pred_gnb))
print(classification_report(y_test, pred_gnb))
print(accuracy_score(y_test, pred_gnb))
# Out:
# [[107  16]
#  [ 36  56]]
#              precision    recall  f1-score   support
#
#           0       0.75      0.87      0.80       123
#           1       0.78      0.61      0.68        92
#
# avg / total       0.76      0.76      0.75       215
#
# 0.758139534884

# %% [markdown]
# **KNN - KNeighborsClassifier**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train_sc,y_train_sc)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=20, p=2,
#            weights='uniform')

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# [[71 52]
#  [26 66]]
#              precision    recall  f1-score   support
#
#           0       0.73      0.58      0.65       123
#           1       0.56      0.72      0.63        92
#
# avg / total       0.66      0.64      0.64       215
#
# 0.637209302326

# %%
knn.fit(X_train_all, y_train_all)
pred_all_knn = knn.predict(X_test_all)

# %%
sub_knn = pd.DataFrame()
sub_knn['PassengerId'] = df_test['PassengerId']
sub_knn['Survived'] = pred_all_knn
#sub_knn.to_csv('knn.csv',index=False)

# %% [markdown]
# **Decision Tree Classifier 1/2**

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
pred_dtree = dtree.predict(X_test)
print(classification_report(y_test,pred_dtree))
print(accuracy_score(y_test, pred_dtree))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.74      0.83      0.78       123
#           1       0.73      0.62      0.67        92
#
# avg / total       0.74      0.74      0.74       215
#
# 0.739534883721

# %% [markdown]
# **Decision Tree Classifier 2/2 (different parameters for max_features, max_depth and min_sample_split)**

# %%
dtree_2 = DecisionTreeClassifier(max_features=7 , max_depth=6,  min_samples_split=8)
dtree_2.fit(X_train,y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.75      0.91      0.82       123
#           1       0.83      0.59      0.69        92
#
# avg / total       0.78      0.77      0.76       215
#
# 0.772093023256

# %% [markdown]
# all data

# %%
dtree_2.fit(X_train_all, y_train_all)
pred_all_dtree2 = dtree_2.predict(X_test_all)

# %% [markdown]
# **Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth=6, max_features=7, min_samples_leaf=10)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=6, max_features=7, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=10, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
pred_rfc = rfc.predict(X_test)
print(confusion_matrix(y_test, pred_rfc))
print(classification_report(y_test, pred_rfc))
print(accuracy_score(y_test, pred_rfc))
# Out:
# [[117   6]
#  [ 35  57]]
#              precision    recall  f1-score   support
#
#           0       0.77      0.95      0.85       123
#           1       0.90      0.62      0.74        92
#
# avg / total       0.83      0.81      0.80       215
#
# 0.809302325581

# %% [markdown]
# Train again for all data and submit

# %%
rfc.fit(X_train_all, y_train_all)
pred_all_rfc = rfc.predict(X_test_all)

# %%
sub_rfc = pd.DataFrame()
sub_rfc['PassengerId'] = df_test['PassengerId']
sub_rfc['Survived'] = pred_all_rfc
#sub_rfc.to_csv('randforest.csv',index=False)

# %% [markdown]
# **SVM Classifier**

# %%
from sklearn.svm import SVC
svc = SVC(gamma = 0.01, C = 100)#, probability=True)
svc.fit(X_train_sc, y_train_sc)
# Out:
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
pred_svc = svc.predict(X_test_sc)
print(confusion_matrix(y_test_sc, pred_svc))
print(classification_report(y_test_sc, pred_svc))
print(accuracy_score(y_test_sc, pred_svc))
# Out:
# [[116   7]
#  [ 34  58]]
#              precision    recall  f1-score   support
#
#           0       0.77      0.94      0.85       123
#           1       0.89      0.63      0.74        92
#
# avg / total       0.82      0.81      0.80       215
#
# 0.809302325581

# %%
svc.fit(X_train_all_sc, y_train_all_sc)
pred_all_svc = svc.predict(X_test_all_sc)

sub_svc = pd.DataFrame()
sub_svc['PassengerId'] = df_test['PassengerId']
sub_svc['Survived'] = pred_all_svc
sub_svc.to_csv('svc.csv',index=False)

# %% [markdown]
# ### 2. K fold cross_validation for 3 classifier
#
# This algorithm splits the data into k sets and then makes k fits using every set k-1 times as training and one time as test data
# It leads to a better estimate for out of sample data  than simple train test split

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# **SVM classifier**

# %%
scores_svc = cross_val_score(svc, X_train_all_sc, y_train_all_sc, cv=10, scoring='accuracy')
print(scores_svc)
print(scores_svc.mean())
# Out:
# [ 0.81944444  0.80555556  0.76388889  0.875       0.81690141  0.8028169
#   0.8028169   0.73239437  0.88732394  0.84507042]
# 0.815121283255

# %% [markdown]
# **Random Forest classifier**

# %%
scores_rfc = cross_val_score(rfc, X_train_all_sc, y_train_all_sc, cv=10, scoring='accuracy')
print(scores_rfc)
print(scores_rfc.mean())
# Out:
# [ 0.76388889  0.76388889  0.76388889  0.875       0.8028169   0.83098592
#   0.8028169   0.73239437  0.85915493  0.8028169 ]
# 0.799765258216

# %% [markdown]
# **DecisionTreeClassifier**

# %%
scores_dtree_2 = cross_val_score(dtree_2, X_train_all_sc, y_train_all_sc, cv=10, scoring='accuracy')
print(scores_dtree_2)
print(scores_dtree_2.mean())
# Out:
# [ 0.70833333  0.77777778  0.75        0.875       0.8028169   0.81690141
#   0.8028169   0.76056338  0.83098592  0.84507042]
# 0.797026604069

# %% [markdown]
# ### 가장 효율이 좋은 모델은  Decision Tree, Random Forest, SVC 임

# %%
print("dtree_2 : " , scores_dtree_2.mean())
print("rfc     : " , scores_rfc.mean())
print("svc     : " , scores_svc.mean())
# Out:
# dtree_2 :  0.797026604069
# rfc     :  0.799765258216
# svc     :  0.815121283255
